# %% [markdown]
# # POLS 2100
#
# ## Week 2, Activity Notebook 1: Working with a Dataset in R
#
# In the lecture notebook you read a dataset, picked out a column with `$`, and took a mean. Here you will do the same steps on a new dataset. Work through the questions in order.

# %% [markdown]
# **How to work through this notebook**
#
# - Run the cells from top to bottom. Use **Shift + Enter** to run a cell.
# - Each question has a cell that reads `# YOUR CODE HERE`. Replace that line with your answer.
# - After you answer, run the check cell below the question to see whether you passed.
# - When you finish, run the last cell to download your notebook, then upload it to Gradescope.

# %% [markdown]
# ## The data
#
# The cell below reads a dataset named `cafe`. It records how many cups of three drinks a campus cafe sold in each of five months. Run it to see the data.
#
# The **codebook** tells you what each column means:
#
# - `Month`: the month of the year
# - `Coffee`: cups of coffee sold that month
# - `Tea`: cups of tea sold that month
# - `Cocoa`: cups of cocoa sold that month

# %%
cafe <- read.csv("cafe.csv")
cafe

# %% [markdown]
# **Question 1.** Use the `$` operator to pull out the `Coffee` column, and assign it to a variable named `coffee.sales`. Then display it.
#
# The pattern is `coffee.sales <- cafe$______`.

# %%
# YOUR CODE HERE

coffee.sales # Don't change this line, it just prints the results

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# **Question 2.** Now pull out the `Cocoa` column the same way, and assign it to `cocoa.sales`. Then display it.
#
# The pattern is `cocoa.sales <- cafe$______`.

# %%
# YOUR CODE HERE

cocoa.sales # Don't change this line

# %%
. = ottr::check("tests/q2.R")

# %% [markdown]
# **Question 3.** Use the `mean()` function to find the average number of coffees sold across the five months. Assign the result to `coffee.mean`, then display it.
#
# The pattern is `coffee.mean <- mean(cafe$______)`.

# %%
# YOUR CODE HERE

coffee.mean # Don't change this line

# %%
. = ottr::check("tests/q3.R")

# %% [markdown]
# **Question 4.** Do the same for cocoa. Assign the average number of cocoas sold to `cocoa.mean`, then display it.

# %%
# YOUR CODE HERE

# (how do you display cocoa.mean?)

# %%
. = ottr::check("tests/q4.R")

# %% [markdown]
# **Question 5.** In an average month, how many more coffees than cocoas did the cafe sell? Use your two variables from Questions 3 and 4 to find the difference, and assign it to `coffee.cocoa.gap`. Then display it.
#
# The pattern is `coffee.cocoa.gap <- coffee.mean - cocoa.mean`.

# %%
# YOUR CODE HERE

# %%
. = ottr::check("tests/q5.R")

# %% [markdown]
# ## Submitting your work
#
# You are done. Run the cell that appears below this one after you process the notebook with Otter; it will check all of your answers and save a file to download. Upload that file to Gradescope.
#
# (While you are writing the assignment, this closing cell is a placeholder. When you run `otter assign`, Otter adds the check-all and export cells here.)

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
ottr::export("Week2_Activity1.ipynb", pdf = TRUE)
