# %% [markdown]
# # POLS 2100
#
# ## Week 1, Activity Notebook 1: Getting to know you!

# %% [markdown]
# This document is a Jupyter notebook. You'll be working with a notebook almost every day in POLS 2100.
#
# Notebooks allow you to access datasets and run R code from a web browser, so you don't have to download any software or files onto your computer. Often, you'll also be able to get feedback on your code in real time! More on this next week.
#
# There's no coding or math in this notebook, though --- just some open-ended questions to give you space to reflect on your goals for our time together and help me get to know you.

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Question 1
#
# What brings you to POLS 2100?
#
# Are you a Political Science major, or are you joining us from another department? Why did you choose to enroll? How did you come to be in this classroom today? (Feel free to interpret this question as broadly or as narrowly as you'd like.)

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ### Question 2
#
# What previous quantitative experience are you bringing with you?
#
# Have you taken a statistics course before? Where, when, and what was it? Have you encountered programming in R or another language before?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ### Question 3
#
# What previous political science experience are you bringing with you?
#
# Have you taken political science or other social science courses before? Which ones? Are their areas or topics of political science in which you are especially interested in?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ### Question 4
#
# What do you anticipate being exciting or enjoyable about this course? What do you anticipate will be challenging?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ### Question 5
#
# What are your goals for our time together? What do you want to learn, practice, or accomplish in this class that would make you look back on it as a success?
#
# Try to come up with at least one goal beyond "get a good grade." Grades are often a strong extrinsic motivator, but researchers have found that students who are *intrinsically* motivated tend to end up with higher grades --- in other words, setting more personal goals might help you get the grade you want, too!

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ### Question 6
#
# Is there anything else you want to tell me at this point?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# Run the code chunk below by selecting the cell and hitting run.

# %%
. = ottr::check("tests/participation.R")
# Out:
# All tests passed!

# %% [markdown]
# ![](attachment:40402da4-371f-404d-b32a-5f4bb88d9631.png)
#
# Good luck this semester! Belle believes in you.

# %% [markdown]
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell at the end of the notebook and hit run.
#
# ### 4. Submit the .zip file you just downloaded on Gradescope.

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
ottr::export("Week1_Activity1.ipynb", pdf = TRUE)
