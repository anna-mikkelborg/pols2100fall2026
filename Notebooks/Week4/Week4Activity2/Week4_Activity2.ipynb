# %% [markdown]
# # POLS 2100
# ## Week 4, Activity 2: Replicating hypothesis tests
#
# In this activity, you will continue working with the theory and data from Jackman (1987).
#
# ### Political Institutions and Voter Turnout in the Industrial Democracies
# *Robert W. Jackman, Michigan State University*
#
# > What can account for the differences in voter turnout across nations? One cause of differences in voter turnout among industrial democracies is differences in political institutions and electoral law. Disproportionality in the translation of votes into legislative seats, also known as malapportionment, provides a disincentive to voting, which lowers turnout. Mandatory voting laws produce a disincentive to not vote, increasing turnout. Empirical analyses of average voter-turnout levels in the 1960s across 19 democracies are consistent with these expectations, although Switzerland and the United States appear to be outliers. The results have major implications for the way we interpret national differences in voter-turnout rates.
#
# Let's start by loading the `ggplot2` package and reading in our dataset. There are only 19 countries in the dataset, so rather than using `head()`, we're going to print the entire dataset. You can scroll through the output of the cell below to view all 19 rows.

# %%
# RUN THIS CELL
library(ggplot2)
options(repr.plot.width = 4, repr.plot.height = 3, repr.plot.res = 50)

data <- read.csv('jackman1987_replication_data.csv')
data

# %% [markdown]
# - <code>country</code>: The name of the country.
# - <code>turnout</code>: The rate of voting among voting-age people in the country, averaged across national elections between 1960 and 1970. Ranges from 0 to 100%.
# - <code>elect_disprop</code>: Electoral disproportionality, that is, the average gap between national vote share and seat share in the national legislature for the two largest parties. Higher values mean less proportional systems; 0 indicates perfect proportionality.
# - <code>compulsory_voting</code> A binary indicator for whether voting is required by law in this country. 0 indicates voting is not required; 1 indicates voting is required.

# %% [markdown]
# ------
#
# **Question 1.** First, we will test the hypothesis: "Disproportionality in the translation of votes into legislative seats, also known as malapportionment, provides a disincentive to voting, which lowers turnout."
#
# Make a scatterplot with a line of best fit presenting electoral disproportionality as the independent variable and voter turnout as the dependent variable.

# %%
q1.plot <- NULL # YOUR CODE HERE
q1.plot

# %%
. = ottr::check("tests/q1.R")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ------
#
# **Question 2.** Interpret the plot you made. What is the relationship between electoral disproportionality and voter turnout? Is this relationship surprising to you, or not? Explain why in your own words.

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ------
#
# **Question 3.** One country in the dataset is much more of an outlier than the others in the plot you made. Use the full dataset you printed out to identify this outlier and enter the name of the country as a string (in quotation marks!) below.

# %%
q3.answer <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q3.R")

# %% [markdown]
# ------
#
# **Question 4.** Jackman's abstract notes that two countries — the United States and Switzerland — appear to be outliers. What does the relationship between electoral disproportionality and voter turnout look like if you remove these two countries from the dataset?

# %%
# first, create a subset of the dataset that does not include the United States and Switzerland.
q4.subset <- NULL # YOUR CODE HERE
# next, plot the relationship between electoral disproportionality and voter turnout like you did in Question 1 using the new dataset you just created.
q4.plot <- NULL # YOUR CODE HERE
q4.plot

# %%
. = ottr::check("tests/q4.R")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ------
#
# **Question 5.** Run the code below to view the two plots you've made next to each other.

# %%
q1.plot + ylim(0, 100) + ggtitle("Question 1 plot")
q4.plot + ylim(0, 100) + ggtitle("Question 4 plot")

# %% [markdown]
# Researcher A looks at these plots and says, "after dropping outliers from the dataset, the line of best fit shows a stronger relationship between electoral disproportionality and voter turnout. Since our observations from the U.S. and Switzerland are so different, we should just remove them and publish the results from the second plot."
#
# You are coauthoring this paper with Researcher A. Do you agree or disagree with their suggestion? Why?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ------
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 0. Make sure you have run every cell in the notebook up to this point.
#
# ### 1. Click the floppy disk icon (💾) to save your notebook.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell at the end of the notebook and hit run.
#
# ### 4. Submit the .zip file you just downloaded on [Gradescope.](https://www.gradescope.com/courses/1340931)

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
ottr::export("Week4_Activity2.ipynb", pdf = TRUE)
