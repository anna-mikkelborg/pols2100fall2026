# %% [markdown]
# # POLS 2100
# ## Week 2, Lecture 1: Analyzing Data using R in Jupyter Notebooks
# In this notebook, you will learn about Jupyter Notebooks (like this one!) and the R programming language, which we will use this semester to analyze quantitative data.

# %% [markdown]
# # Jupyter Notebooks
# A Jupyter Notebook is an online, interactive computing environment, composed of different types of **cells.** Cells are chunks of code or text that are used to break up a larger notebook into smaller, more manageable parts and to let the viewer modify and interact with the elements of the notebook.
#
# There are a few advantages of Jupyter notebooks for a class like POLS 2100:
#
# - You don't need to install software on your own computer (and potentially troubleshoot it if it doesn't work)
# - Some answers can be *auto-graded,* so you'll get quick feedback on your performance.
# - For your *group* assignments, you'll see whether you got the right answer *as you're working on the assignment!*
#
# Notice that the notebook consists of 2 different kinds of cells: **text** and **code.** A text cell (like this one) contains plain text, while a code cell contains expressions in R, the programming language that you will be using.

# %% [markdown]
# # Running code cells
# "Running" a cell is similar to pressing "Enter" on a calculator once you've typed in an expression. It computes all of the expressions contained within the cell.
#
# To run a code cell, you can do either of the following:
#
# - Press **Shift + Enter**
# - Click **-> Run** in the toolbar at the top of the screen.
#
# You can navigate the cells by either clicking on them or by using your up and down arrow keys. Try running the cell below to see what happens.

# %%
5 + 5

# %% [markdown]
# The input of the cell consists of the text/code that is contained within the cell's enclosing box. Here, the input is an expression in R that "prints" or repeats whatever text or number is passed in.
#
# The output of running a code cell is shown in the line immediately after it. Notice that text cells have no output.
#
# Each line of a cell runs an operation.

# %%
# Addition
20 + 20

# %%
# Multiplication
10 * 8.5

# %%
# Division
625 / 25

# %%
# A series of arithmetic operations
(2 - 4 * 5 + 7) + 18 * 2
# Out:
# [1] 85

# %% [markdown]
# Note that code after a # (hashtag) is not run, so we use lines starting with hashtags to add comments or notes on our code. Here's an example:

# %%
# By using a comment at the beginning of the cell, we can describe what will occur when you run the code.
# Add 10 to 8
10 + 8 # we can add a comment after the expression, too!

# %% [markdown]
# # R variables
# In R you will often be using **variables** instead of raw numbers. Variables are placeholders for certain values that you can assign and reassign. A variable might be a placeholder for a single value (like in the example below) or a collection of values (more on this later).
#
# For example, let the variables `x` and `y` equal 10 and 9. This action is called "assigning" a variable, and you do it using the `<-` operator.

# %%
# assign your variable by using <-
x <- 10
y <- 9

# %% [markdown]
# Notice that assigning these values to these variables produces no output. We are telling R to use `x` to refer to 10 and `y` to refer to 9. To have R show these values back to us, just type the variable into the coding cell on its own, like this:

# %%
# run this cell to see the value assigned to x
x

# %% [markdown]
# Now, we can use the variables `x` and `y` in mathematical expressions:

# %%
# should be equal to 10 + 9 = 19
x + y

# %% [markdown]
# We can also **reassign** a variable to a new value. Let's change the value of `x`:

# %%
x <- 12 * 2

# %% [markdown]
# Now, values of expressions that rely on `x` will change, too.

# %%
x

# %%
x + y

# %% [markdown]
# **This is why the order in which you run code cells is important.** The value of the expression `x + y` depends on which cells you ran before.

# %%
x <- 5
y <- 20
x + y

# %% [markdown]
# What happens if you try to use a variable without assigning a value to it first?

# %%
x + y + z
# Out:
# --- Error
# object 'x' not found
#
# --- Traceback (most recent call last)
# 2: eval(expr, envir)
# 1: .handleSimpleError(function (cnd)
#     ...

# %% [markdown]
# You'll see that R outputs an error message. R tried to find the value of `z`, but `z` hadn't been defined yet.
#
# **Important:** If you see an error like this in this notebook or future notebooks, the first thing you should try to fix it is to make sure that you have run all the previous cells and that all the variables you are using have values assigned to them.
#
# Edit the next cell to add a numerical value to `z`.

# %%
# add a number to the right of the <-
z <-

# %%
# before you run this code: what will the value of this expression be?
x + y + z

# %% [markdown]
# ## Variable naming conventions
# The variables in the example above are letters, but you can give variables longer names, too. In R, variables can include letters, numbers, underscores, and periods, but they must *begin* with a letter. It's a good idea to name your variables descriptively so that you can remember what they stand for, but briefly enough so that your code doesn't end up clogged with long variable names.

# %%
# use this code cell to create and assign values to at least two variables of your own and combine them into a mathematical expression.

# %% [markdown]
# # Reading in and using datasets
# R is more than a calculator; it's a tool for statistical computing and graphics. Often, we will be reading datasetes into R to analyze them.
#
# During most of the semester, we'll be reading in real datasets from real studies about the real world.
#
# But first we'll start with something simple. In the next cell, we will read a comma-separated values **(CSV) file** that includes demographic information about members of a typical American family. We *assign* this dataset to a variable named `belchers`.

# %%
# this stores, or assigns, the dataset as belchers.
belchers <- read.csv("belchers.csv")

# %% [markdown]
# Running the name of the dataset by itself prints out the dataset. **For the in-class assignment, you'll use the approach in the next cell to answer Question 1.**

# %%
belchers
# Out:
#   Name   Age Height Occupation
# 1 Bob    46  72     Business owner/chef
# 2 Linda  44  68     Co-owner/Server
# 3 Tina   13  52     Student
# 4 Gene   11  48     Student
# 5 Louise  9  46     Student

# %% [markdown]
# - Datasets consist of multiple **rows,** where each row represents one **observation.** For example, in this dataset, one row corresponds to one person in the Belcher family. In other datasets, a row might correspond to a country, date, or some other **unit of analysis.**
# - Datasets also have multiple **columns.** Each column represents one **variable.** In R, variables refer to names to which we have assigned values. But when we are talking about datasets, variables refer to characteristics that can be measured or counted for every observation (that is, every row). For example, in this dataset, each column corresponds to one type of information about each member of the Belcher family.
# - The intersection of a row and a column in a dataset contains the value of one variable for one particular observation. For example, the `belchers` dataset shows that Tina's occupation is Student.
#
# In this class, you'll also see a **codebook** that tells you what each variable means. Here's what the variables mean in this dataset:
#
# - `Name`: The name of each member of the Belcher family
# - `Age`: The age of that person in years
# - `Height`: The height of that person in inches
# - `Occupation`: That person's primary occupation
#
# We can do operations on datasets using R. The template `dataSetName$variableName` allows us to read a specified column in our dataset and return it. (Note that names in R are case-sensitive!)
#
# **For the in-class assignment, you'll use the approach in the next cell to answer Question 2.**

# %%
# dataSetName$variableName gives us the specified column.
belchers$Height
# Out:
# [1] 72 68 52 36 34

# %% [markdown]
# Furthermore, it is possible to do different operations to this variable. Let's compute the mean of the Belcher family's heights. We'll use R's `mean()` function, which computes the average of a given variable.

# %%
mean(belchers$Height)
# Out:
# [1] 57.2

# %% [markdown]
# The average Belcher is just 4 feet and 9.2 inches tall!
#
# You can save the results of an operation into a new variable that contains a single value. **For the in-class assignment, you'll use the approach in the next cell to answer Questions 3 and 4.**

# %%
height.mean <- mean(belchers$Height) # this assigns the value to height.mean
height.mean # this line just prints what is in height.mean
# Out:
# [1] 57.2

# %% [markdown]
# Once we've assigned a variable, they behave just like numbers. So once they're assigned, you can do arithmetic with the variables, too, just like we showed above.
#
# For example, let's say each member of the Belcher family was outfitted with a pair of two-inch-high platform shoes. What is their average height now?

# %%
new.height.mean <- height.mean + 2
new.height.mean
# Out:
# [1] 59.2

# %% [markdown]
# ## A note on variable types
# Not every variable is a number. For example, the `Name` variable is what is called a **string,** because it contains letters and words, not just numbers. If we try to take the `mean()` of `belchers$Name`, we will get an error.

# %%
mean(belchers$Name)
# Out:
# Warning message in mean.default(belchers$Name):
# “argument is not numeric or logical: returning NA”
# [1] NA

# %% [markdown]
# # Conclusion
#
# In this notebook, we covered:
# - Basic types of objects in R, including values, variables, and datasets
# - How to store objects in variables
# - How to view a dataset and perform transformations on values it contains
#
# # More about class
#
# This was *Week 2, Lecture 1.* Next, you'll work on *Week 2, Activity 1.* In that notebook, you'll use what you learned in this notebook to answer very similar problems. Because it's the first week, that notebook will be graded for completion.
#
# You'll answer each week's *Activity Notebook 1* **twice:**
# - You'll first have 20 minutes to answer the questions individually. The notebooks will be available once lecture is over and be due 20 minutes later.
# - You'll then have 15 minutes to answer the *same* questions as a group.
# - Finally, we'll regroup and go over the right answers as a class.
#
# You can ask me for help at any stage!
#
# # Last thing: Downloading your notebook and submitting it to be graded
#
# When you finish assignments, you'll download your notebook and then submit it by uploading it to Gradescope. There will be instructions at the end of the assignments on how to do so.
#
# **You do NOT need to submit THIS notebook. These instructions apply only to the in-class assignments and problem sets, NOT the lecture notebooks (like this one).**
